// %% [markdown]
// # Drag & Drop CSV file "movies.csv" and generate code for reading data from file to DataFrame

// %%
import java.io.File
import javax.imageio.ImageIO
val image = ImageIO.read(File("../src/main/resources/images/csv.png"))
DISPLAY(image)
// Out:
// class java.awt.image.BufferedImage: 512x512 px
